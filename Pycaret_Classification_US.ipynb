# %% [markdown]
# <h1>Profiling a country specific unemployment dataset for Canada, creating an reasonable binary classification threshold, and running classifcation models<h1>
# <h3>Logistic regression may be a reasonable choice of model based on comparison of different modeling options</h3>

# %%
from pycaret.classification import *

# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/rmikula-gmu/cs504_test1_medium_tutorial/main/CS504%20Final%20Datasets%20Revised/US%20Master%20Dataset.csv")

# %%
df2
# Out:
#           Date        Country          State Initial Claims  \
# 0     1/1/2020  United States        Alabama         12,819
# 1     1/1/2020  United States         Alaska          4,536
# 2     1/1/2020  United States        Arizona         15,413
# 3     1/1/2020  United States       Arkansas          8,481
# 4     1/1/2020  United States     California        199,167
# ...        ...            ...            ...            ...
# 1066  9/1/2021  United States       Virginia         34,680
# 1067  9/1/2021  United States     Washington         20,597
# 1068  9/1/2021  United States  West Virginia          3,813
# 1069  9/1/2021  United States      Wisconsin         26,324
# 1070  9/1/2021  United States        Wyoming          1,189
#
#       Avg Insured Unemployment Rate Monthly new case  \
# 0                              0.98                0
# 1                              3.17                0
# 2                              0.64                1
# 3                              1.18                0
# 4                              2.07                0
# ...                             ...              ...
# 1066                           1.18           99,486
# 1067                           2.01           94,585
# 1068                           1.37           50,769
# 1069                           1.45           76,224
# 1070                           0.59           15,466
#
#      Civilian noninstitutional population  Avg Employed Percent of Population  \
# 0                               3,876,526                                56.3
# 1                                 546,109                                61.5
# 2                               5,802,213                                58.8
# 3                               2,353,674                                56.2
# 4                              39,118,595                                60.2
# ...                                   ...                                 ...
# 1066                            6,758,326                                60.4
# 1067                            6,181,559                                60.6
# 1068                            1,435,988                                52.6
# 1069                            4,677,059                                64.0
# 1070                              458,391                                61.2
#
#      Employed Total  Avg Percent of Population  \
# 0         2,180,872                       57.8
# 1           335,692                       64.7
# 2         3,409,624                       61.7
# 3         1,322,159                       58.3
# 4        23,556,224                       63.0
# ...             ...                        ...
# 1066      4,084,410                       62.8
# 1067      3,742,966                       63.7
# 1068        755,769                       55.1
# 1069      2,993,017                       66.6
# 1070        280,427                       64.1
#
#       Avg Unemployed Percent of Labor Force Unemployed Total
# 0                                       2.7           59,405
# 1                                       5.0           17,657
# 2                                       4.8          171,670
# 3                                       3.7           50,132
# 4                                       4.4        1,073,820
# ...                                     ...              ...
# 1066                                    3.8          159,786
# 1067                                    4.9          193,976
# 1068                                    4.6           36,028
# 1069                                    3.9          121,372
# 1070                                    4.5           13,227
#
# [1071 rows x 12 columns]

# %%
df2.shape
# Out:
# (1071, 12)

# %% [markdown]
# <h3>Using an assumption for now that a NaN represents a lack of unemployment applications and benefits processed, so zero may be appropriate</h3>
# <h3>However, some missing data still identified via the profile report below</h3>

# %%
df2.fillna('0')
# Out:
#           Date        Country          State Initial Claims  \
# 0     1/1/2020  United States        Alabama         12,819
# 1     1/1/2020  United States         Alaska          4,536
# 2     1/1/2020  United States        Arizona         15,413
# 3     1/1/2020  United States       Arkansas          8,481
# 4     1/1/2020  United States     California        199,167
# ...        ...            ...            ...            ...
# 1066  9/1/2021  United States       Virginia         34,680
# 1067  9/1/2021  United States     Washington         20,597
# 1068  9/1/2021  United States  West Virginia          3,813
# 1069  9/1/2021  United States      Wisconsin         26,324
# 1070  9/1/2021  United States        Wyoming          1,189
#
#       Avg Insured Unemployment Rate Monthly new case  \
# 0                              0.98                0
# 1                              3.17                0
# 2                              0.64                1
# 3                              1.18                0
# 4                              2.07                0
# ...                             ...              ...
# 1066                           1.18           99,486
# 1067                           2.01           94,585
# 1068                           1.37           50,769
# 1069                           1.45           76,224
# 1070                           0.59           15,466
#
#      Civilian noninstitutional population  Avg Employed Percent of Population  \
# 0                               3,876,526                                56.3
# 1                                 546,109                                61.5
# 2                               5,802,213                                58.8
# 3                               2,353,674                                56.2
# 4                              39,118,595                                60.2
# ...                                   ...                                 ...
# 1066                            6,758,326                                60.4
# 1067                            6,181,559                                60.6
# 1068                            1,435,988                                52.6
# 1069                            4,677,059                                64.0
# 1070                              458,391                                61.2
#
#      Employed Total  Avg Percent of Population  \
# 0         2,180,872                       57.8
# 1           335,692                       64.7
# 2         3,409,624                       61.7
# 3         1,322,159                       58.3
# 4        23,556,224                       63.0
# ...             ...                        ...
# 1066      4,084,410                       62.8
# 1067      3,742,966                       63.7
# 1068        755,769                       55.1
# 1069      2,993,017                       66.6
# 1070        280,427                       64.1
#
#       Avg Unemployed Percent of Labor Force Unemployed Total
# 0                                       2.7           59,405
# 1                                       5.0           17,657
# 2                                       4.8          171,670
# 3                                       3.7           50,132
# 4                                       4.4        1,073,820
# ...                                     ...              ...
# 1066                                    3.8          159,786
# 1067                                    4.9          193,976
# 1068                                    4.6           36,028
# 1069                                    3.9          121,372
# 1070                                    4.5           13,227
#
# [1071 rows x 12 columns]

# %%
profile = ProfileReport(df2, title="US Unemployment")
profile

# %%
profile.to_file("US_Unemployment.html")

# %%
df2["Avg Percent of Population"]
# Out:
# 0       57.8
# 1       64.7
# 2       61.7
# 3       58.3
# 4       63.0
#         ...
# 1066    62.8
# 1067    63.7
# 1068    55.1
# 1069    66.6
# 1070    64.1
# Name: Avg Percent of Population, Length: 1071, dtype: float64

# %% [markdown]
# <h3>Use a classification binary cutoff based on Average Employed Rate</h3>

# %%
#https://www.geeksforgeeks.org/ways-to-apply-an-if-condition-in-pandas-dataframe/

df2.loc[df2["Avg Percent of Population"] >= 62, 'HighEmp'] = 'True'
df2.loc[df2["Avg Percent of Population"] < 62, 'HighEmp'] = 'False'
df2
# Out:
#           Date        Country          State Initial Claims  \
# 0     1/1/2020  United States        Alabama         12,819
# 1     1/1/2020  United States         Alaska          4,536
# 2     1/1/2020  United States        Arizona         15,413
# 3     1/1/2020  United States       Arkansas          8,481
# 4     1/1/2020  United States     California        199,167
# ...        ...            ...            ...            ...
# 1066  9/1/2021  United States       Virginia         34,680
# 1067  9/1/2021  United States     Washington         20,597
# 1068  9/1/2021  United States  West Virginia          3,813
# 1069  9/1/2021  United States      Wisconsin         26,324
# 1070  9/1/2021  United States        Wyoming          1,189
#
#       Avg Insured Unemployment Rate Monthly new case  \
# 0                              0.98                0
# 1                              3.17                0
# 2                              0.64                1
# 3                              1.18                0
# 4                              2.07                0
# ...                             ...              ...
# 1066                           1.18           99,486
# 1067                           2.01           94,585
# 1068                           1.37           50,769
# 1069                           1.45           76,224
# 1070                           0.59           15,466
#
#      Civilian noninstitutional population  Avg Employed Percent of Population  \
# 0                               3,876,526                                56.3
# 1                                 546,109                                61.5
# 2                               5,802,213                                58.8
# 3                               2,353,674                                56.2
# 4                              39,118,595                                60.2
# ...                                   ...                                 ...
# 1066                            6,758,326                                60.4
# 1067                            6,181,559                                60.6
# 1068                            1,435,988                                52.6
# 1069                            4,677,059                                64.0
# 1070                              458,391                                61.2
#
#      Employed Total  Avg Percent of Population  \
# 0         2,180,872                       57.8
# 1           335,692                       64.7
# 2         3,409,624                       61.7
# 3         1,322,159                       58.3
# 4        23,556,224                       63.0
# ...             ...                        ...
# 1066      4,084,410                       62.8
# 1067      3,742,966                       63.7
# 1068        755,769                       55.1
# 1069      2,993,017                       66.6
# 1070        280,427                       64.1
#
#       Avg Unemployed Percent of Labor Force Unemployed Total HighEmp
# 0                                       2.7           59,405   False
# 1                                       5.0           17,657    True
# 2                                       4.8          171,670   False
# 3                                       3.7           50,132   False
# 4                                       4.4        1,073,820    True
# ...                                     ...              ...     ...
# 1066                                    3.8          159,786    True
# 1067                                    4.9          193,976    True
# 1068                                    4.6           36,028   False
# 1069                                    3.9          121,372    True
# 1070                                    4.5           13,227    True
#
# [1071 rows x 13 columns]

# %%
df2["HighEmp"].describe()
# Out:
# count     1071
# unique       2
# top       True
# freq       566
# Name: HighEmp, dtype: object

# %%
from pycaret.classification import *

# %%
#Best to use datetime.strptime here
train=df2[1:714]
test=df2[715:]
train
# Out:
#          Date        Country          State Initial Claims  \
# 1    1/1/2020  United States         Alaska          4,536
# 2    1/1/2020  United States        Arizona         15,413
# 3    1/1/2020  United States       Arkansas          8,481
# 4    1/1/2020  United States     California        199,167
# 5    1/1/2020  United States       Colorado         10,118
# ..        ...            ...            ...            ...
# 709  2/1/2021  United States       Virginia         53,203
# 710  2/1/2021  United States     Washington         58,545
# 711  2/1/2021  United States  West Virginia         15,812
# 712  2/1/2021  United States      Wisconsin         60,850
# 713  2/1/2021  United States        Wyoming          3,845
#
#      Avg Insured Unemployment Rate Monthly new case  \
# 1                             3.17                0
# 2                             0.64                1
# 3                             1.18                0
# 4                             2.07                0
# 5                             0.82                0
# ..                             ...              ...
# 709                           1.75           69,534
# 710                           4.43           27,424
# 711                           3.49           10,854
# 712                           3.80           25,227
# 713                           2.17            2,482
#
#     Civilian noninstitutional population  Avg Employed Percent of Population  \
# 1                                546,109                                61.5
# 2                              5,802,213                                58.8
# 3                              2,353,674                                56.2
# 4                             39,118,595                                60.2
# 5                              4,584,112                                67.0
# ..                                   ...                                 ...
# 709                            6,740,927                                59.6
# 710                            6,140,754                                59.0
# 711                            1,439,233                                51.9
# 712                            4,665,137                                63.1
# 713                              456,315                                61.3
#
#     Employed Total  Avg Percent of Population  \
# 1          335,692                       64.7
# 2        3,409,624                       61.7
# 3        1,322,159                       58.3
# 4       23,556,224                       63.0
# 5        3,070,164                       68.8
# ..             ...                        ...
# 709      4,016,894                       62.8
# 710      3,621,472                       62.5
# 711        746,406                       55.3
# 712      2,942,857                       65.6
# 713        279,794                       64.7
#
#      Avg Unemployed Percent of Labor Force Unemployed Total HighEmp
# 1                                      5.0           17,657    True
# 2                                      4.8          171,670   False
# 3                                      3.7           50,132   False
# 4                                      4.4        1,073,820    True
# 5                                      2.7           84,380    True
# ..                                     ...              ...     ...
# 709                                    5.2          219,727    True
# 710                                    5.6          215,552    True
# 711                                    6.2           49,663   False
# 712                                    3.8          116,563    True
# 713                                    5.3           15,591    True
#
# [713 rows x 13 columns]

# %%
s = setup(data = train, test_data = test, ignore_features=['Avg Percent of Population'],
          target = 'HighEmp', fold_strategy = 'timeseries', fold = 3, session_id = 124)
# Out:
# <style type="text/css">
# #T_66a7c_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_66a7c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66a7c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_66a7c_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_66a7c_row0_col1" class="data row0 col1" >124</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_66a7c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_66a7c_row1_col1" class="data row1 col1" >HighEmp</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_66a7c_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_66a7c_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_66a7c_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_66a7c_row3_col1" class="data row3 col1" >False: 0, True: 1</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_66a7c_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_66a7c_row4_col1" class="data row4 col1" >(713, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_66a7c_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_66a7c_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_66a7c_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_66a7c_row6_col1" class="data row6 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_66a7c_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_66a7c_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_66a7c_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_66a7c_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_66a7c_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_66a7c_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_66a7c_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_66a7c_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_66a7c_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_66a7c_row11_col1" class="data row11 col1" >(713, 313)</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_66a7c_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_66a7c_row12_col1" class="data row12 col1" >(356, 313)</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_66a7c_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_66a7c_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_66a7c_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_66a7c_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_66a7c_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_66a7c_row15_col1" class="data row15 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_66a7c_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_66a7c_row16_col1" class="data row16 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_66a7c_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_66a7c_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_66a7c_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_66a7c_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_66a7c_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_66a7c_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_66a7c_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_66a7c_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_66a7c_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_66a7c_row21_col1" class="data row21 col1" >3033</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_66a7c_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_66a7c_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_66a7c_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_66a7c_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_66a7c_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_66a7c_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_66a7c_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_66a7c_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_66a7c_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_66a7c_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_66a7c_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_66a7c_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_66a7c_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_66a7c_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_66a7c_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_66a7c_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_66a7c_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_66a7c_row30_col1" class="data row30 col1" >None</td>
#     </tr>

# %%
#https://towardsdatascience.com/time-series-forecasting-with-pycaret-regression-module-237b703a0c63
best = compare_models()

# %%
lr=create_model("lr")
prediction_holdout = predict_model(lr)
# Out:
# INFO:logs:Initializing create_model()
# INFO:logs:create_model(estimator=lr, fold=None, round=4, cross_validation=True, predict=True, fit_kwargs=None, groups=None, refit=True, verbose=True, system=True, metrics=None, add_to_model_list=True, display=None, kwargs={})
# INFO:logs:Checking exceptions
# INFO:logs:Preparing display monitor
# IntProgress(value=0, description='Processing: ', max=4)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             23:33:30
# Status     . . . . . . . . . . . . . . . . . .     Finalizing Model
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# Empty DataFrame
# Columns: [Accuracy, AUC, Recall, Prec., F1, Kappa, MCC]
# Index: []
# INFO:logs:Importing libraries
# INFO:logs:Copying training dataset
# INFO:logs:Defining folds
# INFO:logs:Declaring metric variables
# INFO:logs:Importing untrained model
# INFO:logs:Logistic Regression Imported succesfully
# INFO:logs:Starting cross validation
# INFO:logs:Cross validating with TimeSeriesSplit(max_train_size=None, n_splits=3), n_jobs=-1
# INFO:logs:Calculating mean and std
# INFO:logs:Creating metrics dataframe
# INFO:logs:Finalizing model

# %% [markdown]
# <h3>About 79% accuracy on training data, 89% accuracy on test</h3>

# %%
# %matplotlib inline
evaluate_model(lr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3313/3812506233.py in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 evaluate_model(lr)
#
# NameError: name 'lr' is not defined

# %%
#prediction_holdout = predict_model(best);

# %%
#TO DO Debug the tuning command tuned_knn = tune_model('knn')
